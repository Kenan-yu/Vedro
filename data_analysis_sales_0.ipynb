# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_url = "https://raw.githubusercontent.com/FundamentalsPythonYello/data-analysis-0/master/Sales_Data/Sales_April_2019.csv"
df = pd.read_csv(data_url, index_col = 0)
df[:5]
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
#
#               Order Date                      Purchase Address
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001
# NaN                  NaN                                   NaN
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df['Month'] = 'column'
df.head()
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
#
#               Order Date                      Purchase Address   Month
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001  column
# NaN                  NaN                                   NaN  column
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215  column
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  column
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001  column

# %%
df['Month'] = df['Order Date'].str[0:2]
df.head()
# Out:
#                              Product Quantity Ordered Price Each  \
# Order ID
# 176558          USB-C Charging Cable                2      11.95
# NaN                              NaN              NaN        NaN
# 176559    Bose SoundSport Headphones                1      99.99
# 176560                  Google Phone                1        600
# 176560              Wired Headphones                1      11.99
#
#               Order Date                      Purchase Address Month
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# NaN                  NaN                                   NaN   NaN
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04

# %%
df_nan = df[df.isna().any(axis=1)]
df = df.dropna(how = 'all')
df = df[df['Order Date'].str[0:2] != 'Or']

# %%
df['Month'] = df['Month'].astype('int32')
df.head()
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 176558          USB-C Charging Cable                 2       11.95
# 176559    Bose SoundSport Headphones                 1       99.99
# 176560                  Google Phone                 1      600.00
# 176560              Wired Headphones                 1       11.99
# 176561              Wired Headphones                 1       11.99
#
#               Order Date                      Purchase Address  Month   Sales
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# # Convert to right type

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %%
df['Sales'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#                              Product  Quantity Ordered  Price Each  \
# Order ID
# 176558          USB-C Charging Cable                 2       11.95
# 176559    Bose SoundSport Headphones                 1       99.99
# 176560                  Google Phone                 1      600.00
# 176560              Wired Headphones                 1       11.99
# 176561              Wired Headphones                 1       11.99
#
#               Order Date                      Purchase Address  Month   Sales
# Order ID
# 176558    04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 176559    04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 176560    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 176561    04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# # Data Exploration!

# %%
df.groupby('Month').sum()['Sales']
# Out:
# Month
# 4    3.385500e+06
# 5    1.055929e+04
# Name: Sales, dtype: float64

# %%
container = df.groupby('Month').sum()
x = range(1, 3)
y = container['Sales']
plt.bar(x, y, color = 'green')
# Out:
# <BarContainer object of 2 artists>
